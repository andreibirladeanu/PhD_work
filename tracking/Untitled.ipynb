# %%
print ('hello world')
# Out:
# hello world

# %%
print ('hello world')

# %%
print ('hello world')

# %%
import sys
print(sys.version)
# Out:
# 3.10.6 | packaged by conda-forge | (main, Aug 22 2022, 20:41:54) [Clang 13.0.1 ]

# %%
import os
print(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# base

# %%
# !conda list
# Out:
# # packages in environment at /Users/andrei-macpro/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# absl-py                   0.12.0                   pypi_0    pypi
# aiohttp                   3.7.4.post0              pypi_0    pypi
# alabaster                 0.7.12                     py_0
# alembic                   1.5.7                    pypi_0    pypi
# anaconda                  2020.11                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.10.0                   py38_0
# anaconda-project          0.8.4                      py_0
# antlr4-python3-runtime    4.8                      pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# applaunchservices         0.2.1                      py_0
# appnope                   0.1.0                 py38_1001
# appscript                 1.1.1            py38haf1e3a3_0
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38haf1e3a3_1
# argparse                  1.4.0                    pypi_0    pypi
# asn1crypto                1.4.0                      py_0
# asteroid-filterbanks      0.1.0                    pypi_0    pypi
# astroid                   2.4.2                    py38_0
# astropy                   4.0.2            py38haf1e3a3_0
# async-timeout             3.0.1                    pypi_0    pypi
# async_generator           1.10                       py_0
# atomicwrites              1.4.0                      py_0
# attrs                     20.3.0             pyhd3eb1b0_0
# audioread                 2.1.9                    pypi_0    pypi
# autopep8                  1.5.4                      py_0
# babel                     2.8.1              pyhd3eb1b0_0
# backcall                  0.2.0                      py_0
# backports                 1.0                        py_2
# backports.functools_lru_cache 1.6.1                      py_0
# backports.shutil_get_terminal_size 1.0.0                    py38_2
# backports.tempfile        1.0                        py_1
# backports.weakref         1.0.post1                  py_1
# beautifulsoup4            4.9.3              pyhb0f4dca_0
# bitarray                  1.6.1            py38h9ed2024_0
# bkcharts                  0.2                      py38_0
# blas                      1.0                         mkl
# bleach                    3.2.1                      py_0
# blosc                     1.20.1               hab81aa3_0
# bokeh                     2.2.3                    py38_0
# boto                      2.49.0                   py38_0
# bottleneck                1.3.2            py38hf1fa96c_1
# brotlipy                  0.7.0           py38haf1e3a3_1000
# bzip2                     1.0.8                h1de35cc_0
# ca-certificates           2020.10.14                    0
# cachetools                4.2.1                    pypi_0    pypi
# certifi                   2020.6.20          pyhd3eb1b0_3
# cffi                      1.14.3           py38hed5b41f_0
# chardet                   3.0.4                 py38_1003
# click                     7.1.2                      py_0
# cliff                     3.7.0                    pypi_0    pypi
# cloudpickle               1.6.0                      py_0
# clyent                    1.2.2                    py38_1
# cmaes                     0.8.2                    pypi_0    pypi
# cmd2                      1.5.0                    pypi_0    pypi
# colorama                  0.4.4                      py_0
# colorlog                  4.7.2                    pypi_0    pypi
# conda                     4.9.2            py38h50d1736_0    conda-forge
# conda-build               3.20.5                   py38_1
# conda-env                 2.6.0                         1
# conda-package-handling    1.7.2            py38h22f3db7_0
# conda-verify              3.4.2                      py_1
# contextlib2               0.6.0.post1                py_0
# cryptography              3.1.1            py38hddc9c9b_0
# curl                      7.71.1               hb0a8c7a_1
# cycler                    0.10.0                   py38_0
# cython                    0.29.21          py38hb1e8313_0
# cytoolz                   0.11.0           py38haf1e3a3_0
# dask                      2.30.0                     py_0
# dask-core                 2.30.0                     py_0
# dbus                      1.13.18              h18a8e69_0
# decorator                 4.4.2                      py_0
# deep-sort-realtime        1.3.1                    pypi_0    pypi
# defusedxml                0.6.0                      py_0
# diff-match-patch          20200713                   py_0
# dill                      0.2.7.1                  pypi_0    pypi
# distributed               2.30.1           py38hecd8cb5_0
# docopt                    0.6.2                    pypi_0    pypi
# docutils                  0.16                     py38_1
# einops                    0.3.0                    pypi_0    pypi
# entrypoints               0.3                      py38_0
# et_xmlfile                1.0.1                   py_1001
# expat                     2.2.10               hb1e8313_2
# fastcache                 1.1.0            py38h1de35cc_0
# filelock                  3.0.12                     py_0
# fire                      0.4.0                    pypi_0    pypi
# flake8                    3.8.4                      py_0
# flask                     1.1.2                      py_0
# freetype                  2.10.4               ha233b18_0
# fsspec                    0.8.3                      py_0
# future                    0.18.2                   py38_1
# get_terminal_size         1.0.0                h7520d66_0
# gettext                   0.19.8.1             hb0f4f8b_2
# gevent                    20.9.0           py38haf1e3a3_0
# glib                      2.66.1               h9bbe63b_0
# glob2                     0.7                        py_0
# gmp                       6.1.2                hb37e062_1
# gmpy2                     2.0.8            py38h6ef4df4_3
# google-auth               1.28.0                   pypi_0    pypi
# google-auth-oauthlib      0.4.3                    pypi_0    pypi
# greenlet                  0.4.17           py38haf1e3a3_0
# grpcio                    1.36.1                   pypi_0    pypi
# h5py                      2.10.0           py38h3134771_0
# hdf5                      1.10.4               hfa1e0ec_0
# heapdict                  1.0.1                      py_0
# html5lib                  1.1                        py_0
# huggingface-hub           0.0.6                    pypi_0    pypi
# hydra-core                1.0.6                    pypi_0    pypi
# icu                       58.2                 h0a44026_3
# idna                      2.10                       py_0
# imageio                   2.9.0                      py_0
# imagesize                 1.2.0                      py_0
# importlib-metadata        2.0.0                      py_1
# importlib-resources       5.1.2                    pypi_0    pypi
# importlib_metadata        2.0.0                         1
# iniconfig                 1.1.1                      py_0
# intel-openmp              2019.4                      233
# intervaltree              3.1.0                      py_0
# ipykernel                 5.3.4            py38h5ca1d4c_0
# ipython                   7.19.0           py38h01d92e1_0
# ipython_genutils          0.2.0                    py38_0
# ipywidgets                7.5.1                      py_1
# isort                     5.6.4                      py_0
# itsdangerous              1.1.0                      py_0
# jbig                      2.1                  h4d881f8_0
# jdcal                     1.4.1                      py_0
# jedi                      0.17.1                   py38_0
# jinja2                    2.11.2                     py_0
# joblib                    0.17.0                     py_0
# jpeg                      9b                   he5867d9_2
# json5                     0.9.5                      py_0
# jsonschema                3.2.0                      py_2
# jupyter                   1.0.0                    py38_7
# jupyter_client            6.1.7                      py_0
# jupyter_console           6.2.0                      py_0
# jupyter_core              4.6.3                    py38_0
# jupyterlab                2.2.6                      py_0
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_server         1.2.0                      py_0
# keyring                   21.4.0                   py38_1
# kiwisolver                1.3.0            py38h23ab428_0
# krb5                      1.18.2               h75d18d8_0
# lazy-object-proxy         1.4.3            py38h1de35cc_0
# lcms2                     2.11                 h92f6f08_0
# libarchive                3.4.2                haa3ed63_0
# libcurl                   7.71.1               h8a08a2b_1
# libcxx                    10.0.0                        1
# libedit                   3.1.20191231         h1de35cc_1
# libffi                    3.3                  hb1e8313_2
# libgfortran               3.0.1                h93005f0_2
# libiconv                  1.16                 h1de35cc_0
# liblief                   0.10.1               h0a44026_0
# libllvm10                 10.0.1               h76017ad_5
# libpng                    1.6.37               ha441bb4_0
# librosa                   0.8.0                    pypi_0    pypi
# libsodium                 1.0.18               h1de35cc_0
# libspatialindex           1.9.3                h0a44026_0
# libssh2                   1.9.0                ha12b0ac_1
# libtiff                   4.1.0                hcb84e12_1
# libxml2                   2.9.10               h7cdb67c_3
# libxslt                   1.1.34               h83b36ba_0
# llvm-openmp               10.0.0               h28b9765_0
# llvmlite                  0.34.0           py38h739e7dc_4
# locket                    0.2.0                    py38_1
# lxml                      4.6.1            py38h63b7cb6_0
# lz4-c                     1.9.2                h79c402e_3
# lzo                       2.10                 haf1e3a3_2
# mako                      1.1.4                    pypi_0    pypi
# markdown                  3.3.4                    pypi_0    pypi
# markupsafe                1.1.1            py38h1de35cc_1
# matplotlib                3.3.2                         0
# matplotlib-base           3.3.2            py38h181983e_0
# mccabe                    0.6.1                    py38_1
# mistune                   0.8.4           py38h1de35cc_1001
# mkl                       2019.4                      233
# mkl-service               2.3.0            py38hfbe908c_0
# mkl_fft                   1.2.0            py38hc64f4ea_0
# mkl_random                1.1.1            py38h959d312_0
# mock                      4.0.2                      py_0
# more-itertools            8.6.0              pyhd3eb1b0_0
# mpc                       1.1.0                h6ef4df4_1
# mpfr                      4.0.2                h9066e36_1
# mpmath                    1.1.0                    py38_0
# msgpack-numpy             0.4.7.1                  pypi_0    pypi
# msgpack-python            1.0.0            py38h04f5b5a_1
# multidict                 5.1.0                    pypi_0    pypi
# multipledispatch          0.6.0                    py38_0
# navigator-updater         0.2.1                    py38_0
# nb-clean                  2.0.2                    pypi_0    pypi
# nbclient                  0.5.1                      py_0
# nbconvert                 6.0.7                    py38_0
# nbformat                  5.0.8                      py_0
# ncurses                   6.2                  h0a44026_1
# nest-asyncio              1.4.2              pyhd3eb1b0_0
# networkx                  2.5                        py_0
# nltk                      3.5                        py_0
# nose                      1.3.7                 py38_1004
# notebook                  6.1.4                    py38_0
# numba                     0.51.2           py38h6440ff4_1
# numexpr                   2.7.1            py38hce01a72_0
# numpy                     1.19.2           py38h456fd55_0
# numpy-base                1.19.2           py38hcfb5961_0
# numpydoc                  1.1.0              pyhd3eb1b0_1
# oauthlib                  3.1.0                    pypi_0    pypi
# olefile                   0.46                       py_0
# omegaconf                 2.0.6                    pypi_0    pypi
# opencv-python             4.6.0.66                 pypi_0    pypi
# openpyxl                  3.0.5                      py_0
# openssl                   1.1.1h               haf1e3a3_0
# optuna                    2.6.0                    pypi_0    pypi
# packaging                 20.4                       py_0
# pandas                    1.1.3            py38hb1e8313_0
# pandoc                    2.11                 h0dc7051_0
# pandocfilters             1.4.3            py38hecd8cb5_1
# parso                     0.7.0                      py_0
# partd                     1.1.0                      py_0
# path                      15.0.0                   py38_0
# path.py                   12.5.0                        0
# pathlib2                  2.3.5                    py38_1
# pathtools                 0.1.2                      py_1
# patsy                     0.5.1                    py38_0
# pbr                       5.5.1                    pypi_0    pypi
# pcre                      8.44                 hb1e8313_0
# pep8                      1.7.1                    py38_0
# pexpect                   4.8.0                    py38_1
# pickleshare               0.7.5                 py38_1001
# pillow                    8.0.1            py38h5270095_0
# pip                       20.2.4           py38hecd8cb5_0
# pkginfo                   1.6.1            py38hecd8cb5_0
# pluggy                    0.13.1                   py38_0
# ply                       3.11                     py38_0
# pooch                     1.3.0                    pypi_0    pypi
# prettytable               2.1.0                    pypi_0    pypi
# prometheus_client         0.8.0                      py_0
# prompt-toolkit            3.0.8                      py_0
# prompt_toolkit            3.0.8                         0
# protobuf                  3.15.6                   pypi_0    pypi
# psutil                    5.7.2            py38haf1e3a3_0
# ptyprocess                0.6.0                    py38_0
# py                        1.9.0                      py_0
# py-lief                   0.10.1           py38haf313ee_0
# pyannote-audio            0.0.1                    pypi_0    pypi
# pyannote-core             4.1                      pypi_0    pypi
# pyannote-database         4.0.4                    pypi_0    pypi
# pyannote-metrics          3.0.1                    pypi_0    pypi
# pyannote-pipeline         2.0                      pypi_0    pypi
# pyasn1                    0.4.8                    pypi_0    pypi
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycocotools               2.0.4                    pypi_0    pypi
# pycodestyle               2.6.0                      py_0
# pycosat                   0.6.3            py38h1de35cc_1
# pycparser                 2.20                       py_2
# pycurl                    7.43.0.6         py38hddc9c9b_0
# pydocstyle                5.1.1                      py_0
# pydub                     0.25.1                   pypi_0    pypi
# pyflakes                  2.2.0                      py_0
# pygments                  2.7.2              pyhd3eb1b0_0
# pylint                    2.6.0                    py38_0
# pyodbc                    4.0.30           py38h0a44026_0
# pyopenssl                 19.1.0                     py_1
# pyparsing                 2.4.7                      py_0
# pyperclip                 1.8.2                    pypi_0    pypi
# pyqt                      5.9.2            py38h655552a_2
# pyrsistent                0.17.3           py38haf1e3a3_0
# pysocks                   1.7.1                    py38_1
# pytables                  3.6.1            py38h4727e94_0
# pytest                    6.1.1                    py38_0
# python                    3.8.5                h26836e1_1
# python-dateutil           2.8.1                      py_0
# python-editor             1.0.4                    pypi_0    pypi
# python-jsonrpc-server     0.4.0                      py_0
# python-language-server    0.35.1                     py_0
# python-libarchive-c       2.9                        py_0
# python.app                2                       py38_10
# python_abi                3.8                      1_cp38    conda-forge
# pytorch-lightning         1.2.4                    pypi_0    pypi
# pytorch-metric-learning   0.9.97                   pypi_0    pypi
# pytz                      2020.1                     py_0
# pywavelets                1.1.1            py38haf1e3a3_2
# pyyaml                    5.3.1            py38haf1e3a3_1
# pyzmq                     19.0.2           py38hb1e8313_1
# qdarkstyle                2.8.1                      py_0
# qt                        5.9.7                h468cd18_1
# qtawesome                 1.0.1                      py_0
# qtconsole                 4.7.7                      py_0
# qtpy                      1.9.0                      py_0
# readline                  8.0                  h1de35cc_0
# regex                     2020.10.15       py38haf1e3a3_0
# requests                  2.24.0                     py_0
# requests-oauthlib         1.3.0                    pypi_0    pypi
# resampy                   0.2.2                    pypi_0    pypi
# ripgrep                   12.1.1                        0
# rope                      0.18.0                     py_0
# rsa                       4.7.2                    pypi_0    pypi
# rtree                     0.9.4                    py38_1
# ruamel_yaml               0.15.87          py38haf1e3a3_1
# scikit-image              0.17.2           py38h81aa140_0
# scikit-learn              0.23.2           py38h959d312_0
# scipy                     1.5.2            py38h2515648_0
# seaborn                   0.11.0                     py_0
# semver                    2.13.0                   pypi_0    pypi
# send2trash                1.5.0                    py38_0
# setuptools                50.3.1           py38hecd8cb5_1
# shellingham               1.4.0                    pypi_0    pypi
# simplegeneric             0.8.1                    py38_2
# simplejson                3.17.2                   pypi_0    pypi
# singledispatch            3.4.0.3                 py_1001
# sip                       4.19.8           py38h0a44026_0
# six                       1.15.0           py38hecd8cb5_0
# slidingwindow             0.0.14                   pypi_0    pypi
# snowballstemmer           2.0.0                      py_0
# sortedcollections         1.2.1                      py_0
# sortedcontainers          2.2.2                      py_0
# soundfile                 0.10.3.post1             pypi_0    pypi
# soupsieve                 2.0.1                      py_0
# sphinx                    3.2.1                      py_0
# sphinxcontrib             1.0                      py38_1
# sphinxcontrib-applehelp   1.0.2                      py_0
# sphinxcontrib-devhelp     1.0.2                      py_0
# sphinxcontrib-htmlhelp    1.0.3                      py_0
# sphinxcontrib-jsmath      1.0.1                      py_0
# sphinxcontrib-qthelp      1.0.3                      py_0
# sphinxcontrib-serializinghtml 1.1.4                      py_0
# sphinxcontrib-websupport  1.2.4                      py_0
# spyder                    4.1.5                    py38_0
# spyder-kernels            1.9.4                    py38_0
# sqlalchemy                1.3.20           py38h9ed2024_0
# sqlite                    3.33.0               hffcf06c_0
# statsmodels               0.12.0           py38haf1e3a3_0
# stevedore                 3.3.0                    pypi_0    pypi
# sympy                     1.6.2            py38hecd8cb5_1
# tabulate                  0.8.9                    pypi_0    pypi
# tblib                     1.7.0                      py_0
# tensorboard               2.4.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.0                    pypi_0    pypi
# tensorpack                0.11                     pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.9.1                    py38_0
# testpath                  0.4.4                      py_0
# tf-pose                   0.1.1                    pypi_0    pypi
# threadpoolctl             2.1.0              pyh5ca1d4c_0
# tifffile                  2020.10.1        py38h0cf3a3e_2
# tk                        8.6.10               hb0a8c7a_0
# toml                      0.10.1                     py_0
# toolz                     0.11.1                     py_0
# torch                     1.8.0                    pypi_0    pypi
# torch-audiomentations     0.6.0                    pypi_0    pypi
# torchaudio                0.8.0                    pypi_0    pypi
# torchvision               0.9.0                    pypi_0    pypi
# tornado                   6.0.4            py38h1de35cc_1
# tqdm                      4.50.2                     py_0
# traitlets                 5.0.5                      py_0
# typer                     0.3.2                    pypi_0    pypi
# typing_extensions         3.7.4.3                    py_0
# ujson                     4.0.1            py38hb1e8313_0
# unicodecsv                0.14.1                   py38_0
# unixodbc                  2.3.9                haf1e3a3_0
# urllib3                   1.25.11                    py_0
# watchdog                  0.10.3           py38haf1e3a3_0
# wcwidth                   0.2.5                      py_0
# webencodings              0.5.1                    py38_1
# werkzeug                  1.0.1                      py_0
# wheel                     0.35.1                     py_0
# widgetsnbextension        3.5.1                    py38_0
# wrapt                     1.11.2           py38h1de35cc_0
# wurlitzer                 2.0.1                    py38_0
# xlrd                      1.2.0                      py_0
# xlsxwriter                1.3.7                      py_0
# xlwings                   0.20.8                   py38_0
# xlwt                      1.3.0                    py38_0
# xmltodict                 0.12.0                     py_0
# xz                        5.2.5                h1de35cc_0
# yaml                      0.2.5                haf1e3a3_0
# yapf                      0.30.0                     py_0
# yarl                      1.6.3                    pypi_0    pypi
# zeromq                    4.3.3                hb1e8313_3
# zict                      2.0.0                      py_0
# zipp                      3.4.0              pyhd3eb1b0_0
# zlib                      1.2.11               h1de35cc_3
# zope                      1.0                      py38_1
# zope.event                4.5.0                    py38_0
# zope.interface            5.1.2            py38haf1e3a3_0
# zstd                      1.4.5                h41d2c2f_0

# %%
conda install python=3.8.5

# %%
conda install python=3.8

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-912caa3ad434> in <module>
# ----> 1 get_ipython().run_line_magic('conda', 'list')
#
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-100> in conda(self, line)
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magics/packaging.py in conda(self, line)
#      77         """
#      78         if not _is_conda_environment():
# ---> 79             raise ValueError("The python kernel does not appear to be a conda environment.  "
#      80                              "Please use ``%pip install`` instead.")
#      81
#
# ValueError: The python kernel does not appear to be a conda environment.  Please use ``%pip install`` instead.

# %%
jupyter --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 jupyter --version
#
# NameError: name 'jupyter' is not defined

# %%
pip install jupyter-ai
# Out:
# Collecting jupyter-ai
#   Downloading jupyter_ai-2.12.0-py3-none-any.whl (929 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 929.3/929.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting dask[distributed]
#   Downloading dask-2024.3.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.4 MB/s eta 0:00:0000:0100:01
# Collecting deepmerge>=1.0
#   Downloading deepmerge-1.1.1-py3-none-any.whl (8.6 kB)
# Collecting typing-extensions>=4.5.0
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.6.0-cp310-cp310-macosx_10_9_x86_64.whl (999 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 999.9/999.9 kB 1.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jupyterlab~=4.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-ai) (4.1.5)
# Collecting aiosqlite>=0.18
#   Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: traitlets>=5.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-ai) (5.14.2)
# Requirement already satisfied: jupyter-server<3,>=1.6 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-ai) (2.13.0)
# Collecting importlib-metadata>=5.2.0
#   Downloading importlib_metadata-7.0.2-py3-none-any.whl (24 kB)
# Collecting jupyter-ai-magics
#   Downloading jupyter_ai_magics-2.12.0-py3-none-any.whl (27 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp310-cp310-macosx_10_14_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 1.3 MB/s eta 0:00:0000:0100:01
# Collecting zipp>=0.5
#   Downloading zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: packaging in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (21.3)
# Requirement already satisfied: anyio>=3.1.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (3.6.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (0.9.1)
# Requirement already satisfied: overrides in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (7.7.0)
# Requirement already satisfied: jinja2 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (3.1.2)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (7.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (5.7.2)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (1.8.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (8.6.1)
# Requirement already satisfied: prometheus-client in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (0.14.1)
# Requirement already satisfied: pyzmq>=24 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (24.0.1)
# Requirement already satisfied: terminado>=0.8.3 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (0.15.0)
# Requirement already satisfied: websocket-client in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (1.4.1)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (5.6.0)
# Requirement already satisfied: argon2-cffi in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (21.3.0)
# Requirement already satisfied: jupyter-server-terminals in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (0.5.3)
# Requirement already satisfied: tornado>=6.2.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-server<3,>=1.6->jupyter-ai) (6.2)
# Requirement already satisfied: ipykernel in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab~=4.0->jupyter-ai) (6.15.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab~=4.0->jupyter-ai) (2.2.4)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab~=4.0->jupyter-ai) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab~=4.0->jupyter-ai) (0.27.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.19.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab~=4.0->jupyter-ai) (2.25.4)
# Requirement already satisfied: tomli in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab~=4.0->jupyter-ai) (2.0.1)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab~=4.0->jupyter-ai) (0.2.4)
# Collecting click>=8.1
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Collecting toolz>=0.10.0
#   Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.9 MB/s eta 0:00:00
# Collecting fsspec>=2021.09.0
#   Downloading fsspec-2024.3.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.9/171.9 kB 520.6 kB/s eta 0:00:00a 0:00:01
# Collecting partd>=1.2.0
#   Downloading partd-1.4.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from dask[distributed]->jupyter-ai) (6.0.1)
# Collecting distributed==2024.3.1
#   Downloading distributed-2024.3.1-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 758.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: psutil>=5.7.2 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from distributed==2024.3.1->dask[distributed]->jupyter-ai) (5.9.2)
# Collecting locket>=1.0.0
#   Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msgpack>=1.0.0
#   Downloading msgpack-1.0.8-cp310-cp310-macosx_10_9_x86_64.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 3.4 MB/s eta 0:00:00
# Collecting tblib>=1.6.0
#   Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: urllib3>=1.24.3 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from distributed==2024.3.1->dask[distributed]->jupyter-ai) (1.26.12)
# Collecting sortedcontainers>=2.0.5
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting zict>=3.0.0
#   Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from faiss-cpu->jupyter-ai) (1.23.3)
# Requirement already satisfied: ipython in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-ai-magics->jupyter-ai) (8.5.0)
# Collecting langchain<0.2.0,>=0.1.0
#   Downloading langchain-0.1.12-py3-none-any.whl (809 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 669.3 kB/s eta 0:00:0000:0100:01
# Collecting jsonpath-ng<2,>=1.5.3
#   Downloading jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# Collecting regex>=2022.1.18
#   Downloading regex-2023.12.25-cp310-cp310-macosx_10_9_x86_64.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.26.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from tiktoken->jupyter-ai) (2.31.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.6->jupyter-ai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.6->jupyter-ai) (3.4)
# Requirement already satisfied: httpcore==1.* in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab~=4.0->jupyter-ai) (1.0.4)
# Requirement already satisfied: certifi in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab~=4.0->jupyter-ai) (2022.9.14)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab~=4.0->jupyter-ai) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jinja2->jupyter-server<3,>=1.6->jupyter-ai) (2.1.1)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.6->jupyter-ai) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=1.6->jupyter-ai) (4.2.0)
# Requirement already satisfied: referencing in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (0.34.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (2.0.7)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (4.21.1)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (0.1.4)
# Requirement already satisfied: babel>=2.10 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab~=4.0->jupyter-ai) (2.10.3)
# Requirement already satisfied: json5>=0.9.0 in /Users/andrei-macpro/anaconda3/envs/deepsort/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab~=4.0->jupyter-ai) (0.9.10)
# Collecting langchain-community<0.1,>=0.0.28
#   Downloading langchain_community-0.0.28-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 870.7 kB/s eta 0:00:00a 0:00:01
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.9.3-cp310-cp310-macosx_10_9_x86_64.whl (397 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.9/397.9 kB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting SQLAlchemy<3,>=1.4
#   Downloading SQLAlchemy-2.0.28-cp310-cp310-macosx_10_9_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 1.2/2.1 MB 1.0 MB/s eta 0:00:010m
